# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Vin/Mask_RCNN/samples
# Out:
# /content/drive/MyDrive/Vin/Mask_RCNN/samples

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2021-01-19 02:08:23--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.229.59.32, 54.85.41.146, 34.225.127.47, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.229.59.32|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.3’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  28.0MB/s    in 0.5s
#
# 2021-01-19 02:08:23 (28.0 MB/s) - ‘ngrok-stable-linux-amd64.zip.3’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok

# %%
LOG_DIR = '/content/drive/MyDrive/Vin/logs/city_small20210114T0842'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://6d6d694c42aa.ngrok.io

# %%
cd /usr/local/lib/python3.6/dist-packages/tensorboard/
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorboard

# %%
# !python main.py --logdir=/content/drive/MyDrive/Vin/logs/city_small20210114T0842
# Out:
# 2021-01-19 02:08:40.593101: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.4.0 at http://localhost:6006/ (Press CTRL+C to quit)
# W0119 02:08:43.705495 139950655616768 plugin_event_accumulator.py:322] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0119 02:08:43.746935 139950655616768 plugin_event_accumulator.py:334] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# W0119 02:08:44.665945 139950655616768 plugin_event_accumulator.py:322] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# ...
